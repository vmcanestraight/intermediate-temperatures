# %%
import matplotlib.pyplot as plt
import numpy as np
import VMC_colors as vc

import importlib
importlib.reload(vc)
# Out:
# <module 'VMC_colors' from 'c:\\Users\\vcane\\OneDrive - Harvard University\\Lab Shared Files\\Code\\synthesis_temp_distribution\\scifinder\\formatting\\VMC_colors.py'>

# %%
plt.style.use('vmc_colors.mplstyle')

# %%
vc.get_color('blue')
# Out:
# '#2c457d'

# %% [markdown]
# ["#2c457d","#50c5db","#fe8f06","#4b8163","#e30291","#c6c0fe","#48006a","#e60027","#c0e087"]

# %%
# Create a scatterplot
plt.figure(figsize=(4,3))
x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x, y)

x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x, y, color = vc.get_color(3))


plt.title('Scatterplot of Randomly Sampled Points')
plt.xlabel('X values')
plt.ylabel('Y values')
# Out:
# Text(0, 0.5, 'Y values')

# %%
data = np.random.randn(1000)

# Create a histogram using the viridis colormap
plt.figure(figsize=(6, 6))
plt.imshow(plt.imread('colormaptester.jpeg'), cmap=vc.get_cmap('faux_inferno'))
plt.colorbar()  # Optional: add a colorbar
plt.title('Grayscale Image with Plasma Colormap')
plt.axis('off')  # Optional: hide axis labels
plt.show()
